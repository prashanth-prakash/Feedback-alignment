# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import tensorflow as tf 
import numpy as np 
import pickle
import numpy.random as rng
import matplotlib.pyplot as plt
from scipy.signal import lfilter
# Out:
# /opt/anaconda/miniconda2/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
fo=open('/home/prashanth/cifar-10-batches-py/data_batch_1','rb')
dict=pickle.load(fo)
X=dict[b'data']
Y=dict[b'labels']
fo.close
X=X.reshape((len(X),3,32,32)).transpose(0,2,3,1).astype("uint8")
Y=np.array(Y)

# %%
def forward_conv(weights,input):
    return(tf.nn.conv2d(input,weights,strides=[1,1,1,1],padding="SAME"))

def forward_pooling_layer(inp):
    return(tf.nn.max_pool(value=inp,ksize=[1,2,2,1],strides=[1,1,1,1],padding="SAME"))

def flatten_forward(layer):
    inp_list=layer.get_shape().as_list()
    new_size = inp_list[-1] * inp_list[-2] * inp_list[-3]
    return tf.reshape(layer,[-1,new_size]),new_size

def fc_forward(layer,weights):
    return tf.matmul(layer,weights)

def activation(layer):
    return tf.nn.relu(layer)

# %%
filter_random = tf.Variable(rng.randn(5,5,3,32), dtype = tf.float32)

@tf.RegisterGradient("CustomConv")
def _conv2d(op,grad):
    print("in override backprop")
    input = op.inputs[0]
    filter = op.inputs[1]
    in_shape = tf.shape(input)
    f_shape = tf.shape(filter)
    g_input = tf.nn.conv2d_backprop_input(input_sizes = in_shape, filter = filter_random, out_backprop = grad, strides = [1,1,1,1], padding = "SAME")
    g_filter = tf.nn.conv2d_backprop_filter(input, filter_sizes = f_shape, out_backprop = grad, strides = [1,1,1,1], padding = "SAME")
    return g_input, g_filter

# %% [markdown]
# # Forward pass

# %%
batch=100
iterations=10000

# %%
filter_conv=tf.Variable(rng.randn(5,5,3,32), dtype = tf.float32) #constant
images=tf.placeholder(tf.float32,shape=(batch,32,32,3),name='images')
true_labels=tf.placeholder(tf.float32,shape=(batch,10),name='true_labels')

#net_conv=forward_conv(filter_conv,images)

g=tf.get_default_graph()
with g.gradient_override_map({"Conv2D": "CustomConv"}):
    net_conv=tf.nn.conv2d(images,filter_conv,strides=[1,1,1,1],padding="SAME")

net_pool= forward_pooling_layer(net_conv)

net_act=activation(net_pool)

net_flatten,new_size=flatten_forward(net_act)

#full-connect
no_of_classes=10

filter_fc=tf.Variable(rng.randn(new_size,no_of_classes),dtype=tf.float32) #constant

net_fc=fc_forward(net_flatten,filter_fc)

output=net_fc

e= net_fc-true_labels #required?

#compute loss
cost = tf.reduce_sum(tf.pow(e, 2))/2
cross_entropy=tf.nn.softmax_cross_entropy_with_logits_v2(logits=
                                  output,labels=true_labels)

# %%
filter_conv_bp=tf.Variable(rng.randn(5,5,3,32), dtype = tf.float32)
net_conv_bp = forward_conv(filter_conv_bp,images)
net_pool_bp = forward_pooling_layer(net_conv_bp)
net_act_bp=activation(net_pool_bp)
net_flatten_bp,new_size_bp=flatten_forward(net_act_bp)

#full-connect
no_of_classes=10
filter_fc_bp=tf.Variable(rng.randn(new_size,no_of_classes),dtype=tf.float32)
net_fc_bp=fc_forward(net_flatten_bp,filter_fc_bp)

output_bp=net_fc_bp
e= net_fc-true_labels 

#compute loss
cost_bp = tf.reduce_sum(tf.pow(e, 2))/2
cross_entropy_bp=tf.nn.softmax_cross_entropy_with_logits_v2(logits=
                                  output_bp,labels=true_labels)

# %%
accuracy_fa=tf.reduce_mean(tf.cast(tf.equal(tf.argmax(output,1),tf.argmax(true_labels,1)),tf.float32))
accuracy_bp=tf.reduce_mean(tf.cast(tf.equal(tf.argmax(output_bp,1),tf.argmax(true_labels,1)),tf.float32))

# %%
#BP gradients
bp_grad = tf.gradients(cross_entropy_bp, images)

override_grad = tf.gradients(cross_entropy, images)
# Out:
# in override backprop

# %%
train_op_bp = tf.train.MomentumOptimizer(learning_rate=0.0000001,momentum=0.9).minimize(cross_entropy_bp)
train_op_fa=tf.train.MomentumOptimizer(learning_rate=0.0000001,momentum=0.9).minimize(cross_entropy)
# Out:
# in override backprop

# %%
a = tf.placeholder(tf.float32, shape=[batch,32,32,3], name="input_placeholder_a")
b = tf.placeholder(tf.float32, shape=[batch,32,32,3], name="input_placeholder_b")
normalize_a=tf.nn.l2_normalize(a,0)
normalize_b=tf.nn.l2_normalize(b,0)
cos_sim=tf.reduce_sum(tf.multiply(normalize_a,normalize_b))

# %%
Y_hot=np.eye(10)[Y]
store_err_bp=[]
store_err_fa=[]
acc_fa=[]
acc_bp=[]
store_align=[]
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for count in range(iterations):
        batch_no=np.random.randint(0,X.shape[0],size=batch)
    
        inp_features=X[batch_no,:,:,:]
        inp_features=inp_features.astype(np.float32)
    
        inp_labels=Y_hot[batch_no,:]
        inp_labels=inp_labels.astype(np.float32)
    
        autobp_input=sess.run(bp_grad,feed_dict={images:inp_features,true_labels:inp_labels})
        override_input=sess.run(override_grad,feed_dict={images:inp_features,true_labels:inp_labels})
        
        sess.run(train_op_bp,feed_dict={images:inp_features,true_labels:inp_labels})
        sess.run(train_op_fa,feed_dict={images:inp_features,true_labels:inp_labels})
        entropy_bp=sess.run(cross_entropy_bp,feed_dict={images:inp_features,true_labels:inp_labels})
        store_err_bp.append(np.mean(entropy_bp))
        entropy_fa=sess.run(cross_entropy,feed_dict={images:inp_features,true_labels:inp_labels})
        store_err_fa.append(np.mean(entropy_fa))
        
        acc_fa.append(sess.run(accuracy_fa,feed_dict={images:inp_features,true_labels:inp_labels}))
        acc_bp.append(sess.run(accuracy_bp,feed_dict={images:inp_features,true_labels:inp_labels}))

        align=sess.run(cos_sim,feed_dict={a:autobp_input[0],b:override_input[0]})
        store_align.append(align)
        if count%100==0:
            print("Iteration:",count)
            print("Cosine Alignment:",align)
# Out:
# ('Iteration:', 0)
# ('Cosine Alignment:', -2.899588)
# ('Iteration:', 100)
# ('Cosine Alignment:', -11.079173)
# ('Iteration:', 200)
# ('Cosine Alignment:', 34.461323)
# ('Iteration:', 300)
# ('Cosine Alignment:', -14.666555)
# ('Iteration:', 400)
# ('Cosine Alignment:', 22.496004)
# ('Iteration:', 500)
# ('Cosine Alignment:', 1.6988788)
# ('Iteration:', 600)
# ('Cosine Alignment:', 24.87009)
# ('Iteration:', 700)
# ('Cosine Alignment:', 9.772556)
# ('Iteration:', 800)
# ('Cosine Alignment:', 23.613256)
# ('Iteration:', 900)
# ('Cosine Alignment:', -4.568325)
# ('Iteration:', 1000)
# ('Cosine Alignment:', 31.357481)
# ('Iteration:', 1100)
# ('Cosine Alignment:', 10.199629)
# ('Iteration:', 1200)
# ('Cosine Alignment:', -46.725544)
# ('Iteration:', 1300)
# ('Cosine Alignment:', 2.1012325)
# ('Iteration:', 1400)
# ('Cosine Alignment:', 7.915162)
# ('Iteration:', 1500)
# ('Cosine Alignment:', -11.919321)
# ('Iteration:', 1600)
# ('Cosine Alignment:', 3.8151636)
# ('Iteration:', 1700)
# ('Cosine Alignment:', -14.352663)
# ('Iteration:', 1800)
# ('Cosine Alignment:', 5.846327)
# ('Iteration:', 1900)
# ('Cosine Alignment:', 16.101185)
# ('Iteration:', 2000)
# ('Cosine Alignment:', 6.9030256)
# ('Iteration:', 2100)
# ('Cosine Alignment:', 24.640934)
# ('Iteration:', 2200)
# ('Cosine Alignment:', -39.852882)
# ('Iteration:', 2300)
# ('Cosine Alignment:', 2.1649537)
# ('Iteration:', 2400)
# ('Cosine Alignment:', 27.768902)
# ('Iteration:', 2500)
# ('Cosine Alignment:', -27.209845)
# ('Iteration:', 2600)
# ('Cosine Alignment:', 12.487261)
# ('Iteration:', 2700)
# ('Cosine Alignment:', 1.4047232)
# ('Iteration:', 2800)
# ('Cosine Alignment:', -35.467865)
# ('Iteration:', 2900)
# ('Cosine Alignment:', 12.608561)
# ('Iteration:', 3000)
# ('Cosine Alignment:', 27.567556)
# ('Iteration:', 3100)
# ('Cosine Alignment:', 52.78712)
# ('Iteration:', 3200)
# ('Cosine Alignment:', -10.353188)
# ('Iteration:', 3300)
# ('Cosine Alignment:', 36.68459)
# ('Iteration:', 3400)
# ('Cosine Alignment:', -22.463154)
# ('Iteration:', 3500)
# ('Cosine Alignment:', 13.223995)
# ('Iteration:', 3600)
# ('Cosine Alignment:', 2.7870076)
# ('Iteration:', 3700)
# ('Cosine Alignment:', -1.1640788)
# ('Iteration:', 3800)
# ('Cosine Alignment:', -10.741184)
# ('Iteration:', 3900)
# ('Cosine Alignment:', 5.805518)
# ('Iteration:', 4000)
# ('Cosine Alignment:', 16.584593)
# ('Iteration:', 4100)
# ('Cosine Alignment:', 0.0)
# ('Iteration:', 4200)
# ('Cosine Alignment:', 14.922795)
# ('Iteration:', 4300)
# ('Cosine Alignment:', -41.406017)
# ('Iteration:', 4400)
# ('Cosine Alignment:', 9.16345)
# ('Iteration:', 4500)
# ('Cosine Alignment:', 3.4191875)
# ('Iteration:', 4600)
# ('Cosine Alignment:', 27.739822)
# ('Iteration:', 4700)
# ('Cosine Alignment:', 0.0)
# ('Iteration:', 4800)
# ('Cosine Alignment:', 1.2138219)
# ('Iteration:', 4900)
# ('Cosine Alignment:', -7.0)
# ('Iteration:', 5000)
# ('Cosine Alignment:', 11.0)
# ('Iteration:', 5100)
# ('Cosine Alignment:', 1.337789)
# ('Iteration:', 5200)
# ('Cosine Alignment:', 62.56884)
# ('Iteration:', 5300)
# ('Cosine Alignment:', -1.8577509e-23)
# ('Iteration:', 5400)
# ('Cosine Alignment:', 8.999727)
# ('Iteration:', 5500)
# ('Cosine Alignment:', -1.0)
# ('Iteration:', 5600)
# ('Cosine Alignment:', 1.553913)
# ('Iteration:', 5700)
# ('Cosine Alignment:', 14.107375)
# ('Iteration:', 5800)
# ('Cosine Alignment:', 7.897158)
# ('Iteration:', 5900)
# ('Cosine Alignment:', 19.664879)
# ('Iteration:', 6000)
# ('Cosine Alignment:', 18.838425)
# ('Iteration:', 6100)
# ('Cosine Alignment:', 25.304455)
# ('Iteration:', 6200)
# ('Cosine Alignment:', 1.1759663)
# ('Iteration:', 6300)
# ('Cosine Alignment:', 9.0)
# ('Iteration:', 6400)
# ('Cosine Alignment:', -3.538663)
# ('Iteration:', 6500)
# ('Cosine Alignment:', -9.613454)
# ('Iteration:', 6600)
# ('Cosine Alignment:', 2.7499664)
# ('Iteration:', 6700)
# ('Cosine Alignment:', 17.846962)
# ('Iteration:', 6800)
# ('Cosine Alignment:', -3.801075)
# ('Iteration:', 6900)
# ('Cosine Alignment:', -27.811235)
# ('Iteration:', 7000)
# ('Cosine Alignment:', -1.0000002)
# ('Iteration:', 7100)
# ('Cosine Alignment:', 3.9999995)
# ('Iteration:', 7200)
# ('Cosine Alignment:', 15.999999)
# ('Iteration:', 7300)
# ('Cosine Alignment:', 34.807137)
# ('Iteration:', 7400)
# ('Cosine Alignment:', 5.987279)
# ('Iteration:', 7500)
# ('Cosine Alignment:', -16.901087)
# ('Iteration:', 7600)
# ('Cosine Alignment:', 14.839235)
# ('Iteration:', 7700)
# ('Cosine Alignment:', -3.98875)
# ('Iteration:', 7800)
# ('Cosine Alignment:', -21.0)
# ('Iteration:', 7900)
# ('Cosine Alignment:', -1.0)
# ('Iteration:', 8000)
# ('Cosine Alignment:', 15.349324)
# ('Iteration:', 8100)
# ('Cosine Alignment:', -1.0294262e-21)
# ('Iteration:', 8200)
# ('Cosine Alignment:', -6.000004)
# ('Iteration:', 8300)
# ('Cosine Alignment:', 50.491817)
# ('Iteration:', 8400)
# ('Cosine Alignment:', 6.907334)
# ('Iteration:', 8500)
# ('Cosine Alignment:', 9.262937)
# ('Iteration:', 8600)
# ('Cosine Alignment:', 0.0)
# ('Iteration:', 8700)
# ('Cosine Alignment:', -9.822548)
# ('Iteration:', 8800)
# ('Cosine Alignment:', 22.518438)
# ('Iteration:', 8900)
# ('Cosine Alignment:', 7.837743)
# ('Iteration:', 9000)
# ('Cosine Alignment:', 6.0000014)
# ('Iteration:', 9100)
# ('Cosine Alignment:', 2.3257146)
# ('Iteration:', 9200)
# ('Cosine Alignment:', 2.8053207)
# ('Iteration:', 9300)
# ('Cosine Alignment:', -12.38657)
# ('Iteration:', 9400)
# ('Cosine Alignment:', 5.359623)
# ('Iteration:', 9500)
# ('Cosine Alignment:', 1.22348284e-17)
# ('Iteration:', 9600)
# ('Cosine Alignment:', -4.999999)
# ('Iteration:', 9700)
# ('Cosine Alignment:', 5.4757395)
# ('Iteration:', 9800)
# ('Cosine Alignment:', -2.2187125e-29)
# ('Iteration:', 9900)
# ('Cosine Alignment:', -9.780935)

# %%
plt.plot(store_err_bp,'r',label='Back prop')
plt.plot(store_err_fa,'b',label='Random feedback')
plt.suptitle('Cross Entropy loss')
plt.ylabel('Cross Entropy loss')
plt.legend()
plt.show()

# %%
plt.semilogy(store_err_bp,label='Back Prop')
plt.semilogy(store_err_fa,label='Random feedback')
plt.title('Cross Entropy on log scale')
plt.ylabel('Cross Entropy loss')
plt.legend()
plt.show()

# %%
plt.plot(acc_bp,label='Back Prop')
plt.plot(acc_fa,label='Random Feedback')
plt.ylabel('Accuracy')
plt.suptitle("Accuracies after 10000 iterations")
plt.legend()
plt.show()

# %%
n = 100 # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy_bp = lfilter(b,a,acc_bp)
yy_fa = lfilter(b,a,acc_fa)

plt.plot( yy_bp, linewidth=2, linestyle="-", c="b",label='BackProp')

plt.plot( yy_fa, linewidth=2, linestyle="-", c="g",label='Random Feedback')
plt.suptitle('After filtering the accuracies')
plt.legend()
plt.ylabel('Accuracy')
plt.show()

# %%
plt.plot(store_align)
plt.suptitle("Cosine Similarity between autobp and overide")
plt.show()

# %%
align
# Out:
# 5.999999

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
import tensorflow as tf 
import numpy as np 
import pickle
import numpy.random as rng
import matplotlib.pyplot as plt
from scipy.signal import lfilter
# Out:
# /opt/anaconda/miniconda2/envs/py34/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Load Training Data

# %%
fo=open('/home/prashanth/cifar-10-batches-py/data_batch_1','rb')
dict=pickle.load(fo,encoding='bytes')
X=dict[b'data']
Y=dict[b'labels']
fo.close
X=X.reshape((len(X),3,32,32)).transpose(0,2,3,1).astype("uint8")
Y=np.array(Y)

# %% [markdown]
# # Load Testing Data

# %%
fo_tst=open('/home/prashanth/cifar-10-batches-py/test_batch','rb')
dict=pickle.load(fo_tst,encoding='bytes')
X_tst=dict[b'data']
Y_tst=dict[b'labels']
fo_tst.close
X_tst=X_tst.reshape((len(X_tst),3,32,32)).transpose(0,2,3,1).astype("uint8")
Y_tst=np.array(Y_tst)

# %%
def forward_conv(height,width,inshape,outshape,input):
    weights=tf.Variable(rng.randn(height,width,inshape,outshape), dtype = tf.float32,name='conv_weights') #constant
    return(tf.nn.conv2d(input,weights,strides=[1,1,1,1],padding="SAME"))

def forward_pooling_layer(inp,window_size):
    return(tf.nn.max_pool(value=inp,ksize=[1,window_size,window_size,1],strides=[1,1,1,1],padding="SAME"))

def flatten_forward(layer):
    inp_list=layer.get_shape().as_list()
    new_size = inp_list[-1] * inp_list[-2] * inp_list[-3]
    return tf.reshape(layer,[-1,new_size]),new_size

def fc_forward(layer,new_size,no_of_classes):
    weights=tf.Variable(rng.randn(new_size,no_of_classes),dtype=tf.float32,name='fc_forward_weights') #constant
    return tf.matmul(layer,weights)

def fc_fc(rows,columns,layers):
    weights=tf.Variable(rng.randn(rows,columns),dtype=tf.float32,name='fc_fc_weights')
    return tf.matmul(layers,weights)

def activation(layer):
    return tf.nn.relu(layer)

# %%
@tf.RegisterGradient("CustomConv")
def _conv2d(op,grad):
    print("in override backprop")
    input = op.inputs[0]
    filter = op.inputs[1]
    in_shape = tf.shape(input)
    f_shape = tf.shape(filter)
    g_input = tf.nn.conv2d_backprop_input(input_sizes = in_shape, filter = filter, out_backprop = grad, strides = [1,1,1,1], padding = "SAME")
    g_filter = tf.nn.conv2d_backprop_filter(input, filter_sizes = f_shape, out_backprop = grad, strides = [1,1,1,1], padding = "SAME")
    return g_input, g_filter

# %%
#PARAMETERS
num_epochs=65
batch=100
iterations=1000
no_of_classes=10
Y_hot=np.eye(no_of_classes)[Y]
Y_hot_tst=np.eye(no_of_classes)[Y_tst]


images=tf.placeholder(tf.float32,shape=(None,32,32,3),name='images')
true_labels=tf.placeholder(tf.float32,shape=(None,10),name='true_labels')

# %% [markdown]
# # Random FeedBack

# %%
#LAYER1
filter_random1 = tf.Variable(rng.randn(5,5,3,20), dtype = tf.float32,name='random_filter1')

g=tf.get_default_graph()
with g.gradient_override_map({"Conv2D": "CustomConv"}):
    net_conv=tf.nn.conv2d(images,filter_random1,strides=[1,1,1,1],padding="SAME")

net_pool= forward_pooling_layer(net_conv,2)
net_act=activation(net_pool)

#LAYER 2
filter_random2 = tf.Variable(rng.randn(5,5,20,50), dtype = tf.float32,name='random_filter2')
with g.gradient_override_map({"Conv2D":"CustomConv"}):
    net_conv2=tf.nn.conv2d(net_act,filter_random2,strides=[1,1,1,1],padding="SAME")
net_pool2= forward_pooling_layer(net_conv2,2)
net_act2=activation(net_pool2)
    
net_flatten,new_size=flatten_forward(net_act2)

net_fc=fc_forward(net_flatten,new_size,500)
net_act3=activation(net_fc)
output=fc_fc(500,no_of_classes,net_act3)

#compute loss

cross_entropy=tf.nn.softmax_cross_entropy_with_logits(logits=
                                  output,labels=true_labels)
cost = tf.reduce_mean(cross_entropy)

# %% [markdown]
# # Back Prop

# %%
# filter_conv_bp=tf.Variable(rng.randn(5,5,3,16), dtype = tf.float32)

#LAYER 1
net_conv_bp= forward_conv(5,5,3,20,images) # height,width,inshape,outshape
net_pool_bp = forward_pooling_layer(net_conv_bp,2) #output,windowsize
net_act_bp=activation(net_pool_bp)

#LAYER2
net_conv_bp2 = forward_conv(5,5,20,50,net_act_bp) # height,width,inshape,outshape
net_pool_bp2 = forward_pooling_layer(net_conv_bp2,2) #output,windowsize
net_act_bp2=activation(net_pool_bp2)

net_flatten_bp,new_size_bp=flatten_forward(net_act_bp2)
net_fc_bp1=fc_forward(net_flatten_bp,new_size_bp,500)
net_act_bp3=activation(net_fc_bp1)
output_bp=fc_fc(500,no_of_classes,net_act_bp3)


#cross_entropy_bp=tf.nn.softmax_cross_entropy_with_logits_v2(logits=
#                                  output_bp,labels=true_labels)
cross_entropy_bp=tf.nn.softmax_cross_entropy_with_logits(logits=
                                  output_bp,labels=true_labels)
cost_bp=tf.reduce_mean(cross_entropy_bp)

# %%
accuracy_fa=tf.reduce_mean(tf.cast(tf.equal(tf.argmax(output,1),tf.argmax(true_labels,1)),tf.float32))
accuracy_bp=tf.reduce_mean(tf.cast(tf.equal(tf.argmax(output_bp,1),tf.argmax(true_labels,1)),tf.float32))

# %%
#BP gradients
bp_grad = tf.gradients(cross_entropy_bp, images)

override_grad = tf.gradients(cross_entropy, images)
# Out:
# in override backprop
# in override backprop

# %%
train_op_bp = tf.train.MomentumOptimizer(learning_rate=0.00000001,momentum=0.9).minimize(cost_bp)
train_op_fa=tf.train.MomentumOptimizer(learning_rate=0.00000001,momentum=0.9).minimize(cost)
# Out:
# in override backprop
# in override backprop

# %%
store_err_bp=[]
store_err_fa=[]
acc_fa=[]
acc_bp=[]
testing_fa=[]
testing_bp=[]
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for epoch in range(num_epochs):
        print("\n\t\t\tEPOCH NO:",epoch+1)
        for count in range(iterations):
            batch_no=np.random.randint(0,X.shape[0],size=batch)

            inp_features=X[batch_no,:,:,:]
            inp_features=inp_features.astype(np.float32)

            inp_labels=Y_hot[batch_no,:]
            inp_labels=inp_labels.astype(np.float32)

            autobp_input=sess.run(bp_grad,feed_dict={images:inp_features,true_labels:inp_labels})
            override_input=sess.run(override_grad,feed_dict={images:inp_features,true_labels:inp_labels})

            sess.run(train_op_bp,feed_dict={images:inp_features,true_labels:inp_labels})
            sess.run(train_op_fa,feed_dict={images:inp_features,true_labels:inp_labels})

            entropy_bp=sess.run(cross_entropy_bp,feed_dict={images:inp_features,true_labels:inp_labels})
            store_err_bp.append(np.mean(entropy_bp))
            entropy_fa=sess.run(cross_entropy,feed_dict={images:inp_features,true_labels:inp_labels})
            store_err_fa.append(np.mean(entropy_fa))

            acc_fa.append(sess.run(accuracy_fa,feed_dict={images:inp_features,true_labels:inp_labels}))
            acc_bp.append(sess.run(accuracy_bp,feed_dict={images:inp_features,true_labels:inp_labels}))


            if (count+1)%200==0:
                print("Iteration:",count+1)
                print("BackPropagation:",sess.run(cost_bp,feed_dict={images:inp_features,true_labels:inp_labels}),"\t Feedback:",sess.run(cost,feed_dict={images:inp_features,true_labels:inp_labels}))
                
        tst_fa=sess.run(accuracy_fa,feed_dict={images:X_tst.astype(np.float32),true_labels:Y_hot_tst})
        tst_bp=sess.run(accuracy_bp,feed_dict={images:X_tst.astype(np.float32),true_labels:Y_hot_tst})

        testing_fa.append(tst_fa)
        testing_bp.append(tst_bp)
        
        print("\nAt the end of EPOCH:",epoch+1)
        print("Testing Accuracy:\nBack Propagation",tst_bp,"\tRandom Feedback:",tst_fa)
# Out:
# 			EPOCH NO: 1
# Iteration: 200
# BackPropagation: 79237.28 	 Feedback: 287659.72
# Iteration: 400
# BackPropagation: 50277.176 	 Feedback: 171066.8
# Iteration: 600
# BackPropagation: 21159.904 	 Feedback: 98681.56
# Iteration: 800
# BackPropagation: 23639.615 	 Feedback: 71790.83
# Iteration: 1000
# BackPropagation: 10593.606 	 Feedback: 48932.605
#
# At the end of EPOCH: 1
# Testing Accuracy:
# Back Propagation 0.1118 	Random Feedback: 0.1216
#
# 			EPOCH NO: 2
# Iteration: 200
# BackPropagation: 12170.841 	 Feedback: 55858.047
# Iteration: 400
# BackPropagation: 11204.481 	 Feedback: 43572.535
# Iteration: 600
# BackPropagation: 10317.737 	 Feedback: 44007.35
# Iteration: 800
# BackPropagation: 14690.778 	 Feedback: 41402.113
# Iteration: 1000
# BackPropagation: 5395.991 	 Feedback: 26958.475
#
# At the end of EPOCH: 2
# Testing Accuracy:
# Back Propagation 0.1089 	Random Feedback: 0.1087
#
# 			EPOCH NO: 3
# Iteration: 200
# BackPropagation: 13577.242 	 Feedback: 26717.936
# Iteration: 400
# BackPropagation: 3938.287 	 Feedback: 22909.588
# Iteration: 600
# BackPropagation: 6643.727 	 Feedback: 23435.7
# Iteration: 800
# BackPropagation: 6865.7183 	 Feedback: 22129.723
# Iteration: 1000
# BackPropagation: 3584.1716 	 Feedback: 20911.418
#
# At the end of EPOCH: 3
# Testing Accuracy:
# Back Propagation 0.1069 	Random Feedback: 0.1124
#
# 			EPOCH NO: 4
# Iteration: 200
# BackPropagation: 5167.5596 	 Feedback: 15673.134
# Iteration: 400
# BackPropagation: 6929.1323 	 Feedback: 20066.242
# Iteration: 600
# BackPropagation: 2419.1206 	 Feedback: 15501.749
# Iteration: 800
# BackPropagation: 1694.5337 	 Feedback: 17508.361
# Iteration: 1000
# BackPropagation: 11820.099 	 Feedback: 15266.912
#
# At the end of EPOCH: 4
# Testing Accuracy:
# Back Propagation 0.1051 	Random Feedback: 0.1197
#
# 			EPOCH NO: 5
# Iteration: 200
# BackPropagation: 5524.89 	 Feedback: 11350.98
# Iteration: 400
# BackPropagation: 475.89648 	 Feedback: 10041.86
# Iteration: 600
# BackPropagation: 2996.459 	 Feedback: 10994.315
# Iteration: 800
# BackPropagation: 394.629 	 Feedback: 8078.5405
# Iteration: 1000
# BackPropagation: 1598.66 	 Feedback: 8209.42
#
# At the end of EPOCH: 5
# Testing Accuracy:
# Back Propagation 0.1048 	Random Feedback: 0.1252
#
# 			EPOCH NO: 6
# Iteration: 200
# BackPropagation: 4412.9204 	 Feedback: 9933.09
# Iteration: 400
# BackPropagation: 565.5824 	 Feedback: 7890.3643
# Iteration: 600
# BackPropagation: 7566.313 	 Feedback: 11241.295
# Iteration: 800
# BackPropagation: 455.335 	 Feedback: 7111.515
# Iteration: 1000
# BackPropagation: 3122.836 	 Feedback: 9058.616
#
# At the end of EPOCH: 6
# Testing Accuracy:
# Back Propagation 0.1046 	Random Feedback: 0.1264
#
# 			EPOCH NO: 7
# Iteration: 200
# BackPropagation: 2741.074 	 Feedback: 8874.876
# Iteration: 400
# BackPropagation: 711.45795 	 Feedback: 5336.765
# Iteration: 600
# BackPropagation: 7805.2725 	 Feedback: 8216.982
# Iteration: 800
# BackPropagation: 1729.4567 	 Feedback: 6978.9507
# Iteration: 1000
# BackPropagation: 3403.7224 	 Feedback: 10489.153
#
# At the end of EPOCH: 7
# Testing Accuracy:
# Back Propagation 0.104 	Random Feedback: 0.1228
#
# 			EPOCH NO: 8
# Iteration: 200
# BackPropagation: 8084.4814 	 Feedback: 8098.3164
# Iteration: 400
# BackPropagation: 714.66986 	 Feedback: 7669.4814
# Iteration: 600
# BackPropagation: 658.43744 	 Feedback: 4767.5405
# Iteration: 800
# BackPropagation: 9741.357 	 Feedback: 18257.078
# Iteration: 1000
# BackPropagation: 1467.7499 	 Feedback: 5496.554
#
# At the end of EPOCH: 8
# Testing Accuracy:
# Back Propagation 0.1033 	Random Feedback: 0.1165
#
# 			EPOCH NO: 9
# Iteration: 200
# BackPropagation: 797.4295 	 Feedback: 5703.7344
# Iteration: 400
# BackPropagation: 2313.7168 	 Feedback: 6541.8076
# Iteration: 600
# BackPropagation: 2604.268 	 Feedback: 4652.534
# Iteration: 800
# BackPropagation: 3739.169 	 Feedback: 4749.229
# Iteration: 1000
# BackPropagation: 1017.43835 	 Feedback: 3970.7178
#
# At the end of EPOCH: 9
# Testing Accuracy:
# Back Propagation 0.1036 	Random Feedback: 0.1169
#
# 			EPOCH NO: 10
# Iteration: 200
# BackPropagation: 3247.6436 	 Feedback: 5453.7104
# Iteration: 400
# BackPropagation: 1025.1204 	 Feedback: 5012.49
# Iteration: 600
# BackPropagation: 4500.4917 	 Feedback: 6293.003
# Iteration: 800
# BackPropagation: 1669.058 	 Feedback: 4697.3564
# Iteration: 1000
# BackPropagation: 1401.0339 	 Feedback: 3480.9863
#
# At the end of EPOCH: 10
# Testing Accuracy:
# Back Propagation 0.1031 	Random Feedback: 0.1181
#
# 			EPOCH NO: 11
# Iteration: 200
# BackPropagation: 4077.7725 	 Feedback: 3975.3674
# Iteration: 400
# BackPropagation: 3804.2837 	 Feedback: 5715.2676
# Iteration: 600
# BackPropagation: 1079.0732 	 Feedback: 5818.7227
# Iteration: 800
# BackPropagation: 1097.1998 	 Feedback: 10369.127
# Iteration: 1000
# BackPropagation: 1273.0458 	 Feedback: 4659.6123
#
# At the end of EPOCH: 11
# Testing Accuracy:
# Back Propagation 0.1029 	Random Feedback: 0.1201
#
# 			EPOCH NO: 12
# Iteration: 200
# BackPropagation: 121.96691 	 Feedback: 3958.8853
# Iteration: 400
# BackPropagation: 1476.9519 	 Feedback: 6121.3594
# Iteration: 600
# BackPropagation: 29.880346 	 Feedback: 2529.5996
# Iteration: 800
# BackPropagation: 465.83624 	 Feedback: 3925.009
# Iteration: 1000
# BackPropagation: 425.78378 	 Feedback: 3485.7722
#
# At the end of EPOCH: 12
# Testing Accuracy:
# Back Propagation 0.1023 	Random Feedback: 0.1073
#
# 			EPOCH NO: 13
# Iteration: 200
# BackPropagation: 1019.8141 	 Feedback: 2506.9675
# Iteration: 400
# BackPropagation: 4231.2217 	 Feedback: 4751.6343
# Iteration: 600
# BackPropagation: 226.05042 	 Feedback: 1596.3257
# Iteration: 800
# BackPropagation: 1061.9164 	 Feedback: 4952.0864
# Iteration: 1000
# BackPropagation: 873.6722 	 Feedback: 1478.7638
#
# At the end of EPOCH: 13
# Testing Accuracy:
# Back Propagation 0.1024 	Random Feedback: 0.1209
#
# 			EPOCH NO: 14
# Iteration: 200
# BackPropagation: 3159.282 	 Feedback: 3396.6074
# Iteration: 400
# BackPropagation: 2815.2905 	 Feedback: 3147.5938
# Iteration: 600
# BackPropagation: 4706.8555 	 Feedback: 1482.6587
# Iteration: 800
# BackPropagation: 3122.5671 	 Feedback: 4155.6196
# Iteration: 1000
# BackPropagation: 1222.8456 	 Feedback: 1865.2749
#
# At the end of EPOCH: 14
# Testing Accuracy:
# Back Propagation 0.1025 	Random Feedback: 0.1277
#
# 			EPOCH NO: 15
# Iteration: 200
# BackPropagation: 2703.205 	 Feedback: 1487.1624
# Iteration: 400
# BackPropagation: 2410.0376 	 Feedback: 919.1359
# Iteration: 600
# BackPropagation: 3767.9429 	 Feedback: 1582.8907
# Iteration: 800
# BackPropagation: 680.56604 	 Feedback: 859.1554
# Iteration: 1000
# BackPropagation: 236.51372 	 Feedback: 711.47284
#
# At the end of EPOCH: 15
# Testing Accuracy:
# Back Propagation 0.1024 	Random Feedback: 0.1195
#
# 			EPOCH NO: 16
# Iteration: 200
# BackPropagation: 1423.9799 	 Feedback: 1063.0135
# Iteration: 400
# BackPropagation: 618.3381 	 Feedback: 499.08313
# Iteration: 600
# BackPropagation: 473.7483 	 Feedback: 522.50464
# Iteration: 800
# BackPropagation: 639.92395 	 Feedback: 1967.087
# Iteration: 1000
# BackPropagation: 798.0125 	 Feedback: 1432.139
#
# At the end of EPOCH: 16
# Testing Accuracy:
# Back Propagation 0.1024 	Random Feedback: 0.1153
#
# 			EPOCH NO: 17
# Iteration: 200
# BackPropagation: 1468.0944 	 Feedback: 1304.571
# Iteration: 400
# BackPropagation: 2340.294 	 Feedback: 1358.734
# Iteration: 600
# BackPropagation: 722.9739 	 Feedback: 398.75333
# Iteration: 800
# BackPropagation: 343.47177 	 Feedback: 1474.5535
# Iteration: 1000
# BackPropagation: 20.140427 	 Feedback: 1243.411
#
# At the end of EPOCH: 17
# Testing Accuracy:
# Back Propagation 0.1022 	Random Feedback: 0.1151
#
# 			EPOCH NO: 18
# Iteration: 200
# BackPropagation: 676.20825 	 Feedback: 2219.4636
# Iteration: 400
# BackPropagation: 49.10692 	 Feedback: 1007.66266
# Iteration: 600
# BackPropagation: 807.8445 	 Feedback: 389.0372
# Iteration: 800
# BackPropagation: 352.59644 	 Feedback: 4453.294

# %%
plt.plot(store_err_bp,'r',label='Back prop')
plt.plot(store_err_fa,'b',label='Random feedback')
plt.suptitle('Cross Entropy loss')
plt.ylabel('Cross Entropy loss')
plt.legend()
plt.show()

# %%
plt.semilogy(store_err_bp,label='Back Prop')
plt.semilogy(store_err_fa,label='Random feedback')
plt.title('Cross Entropy on log scale')
plt.ylabel('Cross Entropy loss')
plt.legend()
plt.show()

# %%
plt.plot(acc_bp,label='Back Prop')
plt.plot(acc_fa,label='Random Feedback')
plt.ylabel('Accuracy')
plt.suptitle("Accuracies after 10000 iterations")
plt.legend()
plt.show()

# %%
n = 10 # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy_bp = lfilter(b,a,acc_bp)
yy_fa = lfilter(b,a,acc_fa)

plt.plot( yy_bp, linewidth=2, linestyle="-", c="b",label='BackProp')

plt.plot( yy_fa, linewidth=2, linestyle="-", c="g",label='Random Feedback')
plt.suptitle('After filtering the accuracies')
plt.legend()
plt.ylabel('Accuracy')
plt.show()
